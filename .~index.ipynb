# %% [markdown]
# # Combining DataFrames With Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll gain practice combining DataFrames through concatenation.  You'll also practice executing various types of joins to selectively combine the information stored in the tables!
#
# ## Objectives
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
#
#
# ## Getting Started
#
# You'll start with a quick section to gain practice with concatenating datasets using `pd.concat()`.
#
# ## Concatenating DataFrames
#
# Run the cell below to create some sample DataFrames for us to work with.

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %% [markdown]
# Now that you have multiple DataFrames to work with, you can execute a concatenation to join them together.
#
# In the cell below, concatenate the 3 DataFrames together using the appropriate function.

# %%
combined_df = pd.concat([df1, df2, df3])
print(combined_df)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src="images/er1.png">
#
# ## Setting Join Conditions With Concatenation
#
# You can also specify if the concatenation is an **_Outer Join_** or an **_Inner Join_**.  Next, you'll execute an inner join. Before you do, you need to create another table that contains some overlapping index values with a DataFrame that already exists.
#
# Run the cell below to create the new DataFrame.

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %% [markdown]
# Now, in the cell below, use the `pd.concat()` method to join DataFrames 1 and 4.  However, this time, specify that the `join` is `'inner'`, and `axis=1`.

# %%
df1_and_4_c = pd.concat([df1,df4],join='inner',axis=1)
df1_and_4_c
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %%
df1_and_4 = df1.join(df4,how='inner',lsuffix='_1',rsuffix='_2')
df1_and_4
# Out:
#     A B_1   C D_1 B_2 D_2   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src='images/er2.png'>
#
# You'll notice that in this case, the results returned contain only the rows with indexes that exist in both tables--rows 2 and 3.  The resulting table contains the values for each column in both tables for the rows.
#
# Note that there are many, many ways that you can make full use of the `concat()` functionality in pandas to join DataFrames together--these are just a few of the most common examples pulled from the pandas documentation on the subject.  For a full view of all the ways you can use `pd.concat()`, see the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/merging.html)!
#
# ## Loading In Data
# Now, it's time to move on to working with the Hearthstone cards database.  This database contains information on cards from the popular game, [Hearthstone](https://playhearthstone.com/en-us/)! For full information on the dataset, see the  [kaggle page](https://www.kaggle.com/jeradrose/hearthstone-cards) for this dataset.
#
# This database consists of the following tables:
#
# * _cards_
# * *dust_costs*
# * _entourages_
# * _mechanics_
# * *play_requirements*
#
# Many of rows in each table--but not all--correspond to the same cards. As such, each table contains a column called `card_id` which acts as a **_Primary Key_** for each table.  You'll make use of these keys to **_join_** the different tables together into a single DataFrame.  You'll also experiment with different types of joins to help us decide exactly what information you wish to combine.
#
# Simply run the cell below to import the tables from the database as DataFrames.

# %%
cards_df = pd.read_csv('cards.csv')
dust_df = pd.read_csv('dust.csv')
entourages_df = pd.read_csv('entourages.csv')
mechanics_df = pd.read_csv('mechanics.csv')
play_requirements_df = pd.read_csv('play_requirements.csv')

# %% [markdown]
# Great.  Now, let's set the correct column, `card_id`, as the index column for each of these tables, and then display each to ensure that everything is as expected.
#
# For each of the dataframes you created in the cell above, call the `.set_index()` method and pass in `card_id`.  Also set `inplace=True`.  Then, display the head of each respective DataFrame to ensure everything worked.
#
# **_NOTE:_** Since you are performing this operation in place, running any cell a second time will result in pandas throwing an error.  If you need to run something a second time, restart the kernel using the jupyter notebook menu at the top of the page.

# %%
cards_df.set_index('card_id', inplace=True)
cards_df.head()
# Out:
#            player_class    type                name      set  \
# card_id
# KARA_00_07         MAGE   SPELL       Astral Portal     KARA
# NEW1_008a         DRUID   SPELL   Ancient Teachings  EXPERT1
# BRM_010t2         DRUID  MINION  Druid of the Flame      BRM
# AT_132          NEUTRAL  MINION  Justicar Trueheart      TGT
# OG_141          NEUTRAL  MINION   Faceless Behemoth       OG
#
#                                                          text  cost  attack  \
# card_id
# KARA_00_07           Summon a random <b>Legendary</b> minion.   1.0     NaN
# NEW1_008a                                        Draw a card.   0.0     NaN
# BRM_010t2                                                 NaN   3.0     2.0
# AT_132      <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0
# OG_141                                                    NaN  10.0    10.0
#
#             health     rarity  collectible  \
# card_id
# KARA_00_07     NaN        NaN          NaN
# NEW1_008a      NaN        NaN          NaN
# BRM_010t2      5.0     COMMON          NaN
# AT_132         3.0  LEGENDARY          1.0
# OG_141        10.0     COMMON          1.0
#
#                                                        flavor   race  \
# card_id
# KARA_00_07                                                NaN    NaN
# NEW1_008a                                                 NaN    NaN
# BRM_010t2                                                 NaN  BEAST
# AT_132      It's like putting racing stripes and a giant s...    NaN
# OG_141      Rejected names: Forty-Foot Faceless, Big ol' N...    NaN
#
#            how_to_earn how_to_earn_golden targeting_arrow_text faction  \
# card_id
# KARA_00_07         NaN                NaN                  NaN     NaN
# NEW1_008a          NaN                NaN                  NaN     NaN
# BRM_010t2          NaN                NaN                  NaN     NaN
# AT_132             NaN                NaN                  NaN     NaN
# OG_141             NaN                NaN                  NaN     NaN
#
#             durability
# card_id
# KARA_00_07         NaN
# NEW1_008a          NaN
# BRM_010t2          NaN
# AT_132             NaN
# OG_141             NaN

# %%
dust_df.set_index('card_id', inplace=True)
dust_df.head()
# Out:
#            player_class    type                name      set  \
# card_id
# KARA_00_07         MAGE   SPELL       Astral Portal     KARA
# NEW1_008a         DRUID   SPELL   Ancient Teachings  EXPERT1
# BRM_010t2         DRUID  MINION  Druid of the Flame      BRM
# AT_132          NEUTRAL  MINION  Justicar Trueheart      TGT
# OG_141          NEUTRAL  MINION   Faceless Behemoth       OG
#
#                                                          text  cost  attack  \
# card_id
# KARA_00_07           Summon a random <b>Legendary</b> minion.   1.0     NaN
# NEW1_008a                                        Draw a card.   0.0     NaN
# BRM_010t2                                                 NaN   3.0     2.0
# AT_132      <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0
# OG_141                                                    NaN  10.0    10.0
#
#             health     rarity  collectible  \
# card_id
# KARA_00_07     NaN        NaN          NaN
# NEW1_008a      NaN        NaN          NaN
# BRM_010t2      5.0     COMMON          NaN
# AT_132         3.0  LEGENDARY          1.0
# OG_141        10.0     COMMON          1.0
#
#                                                        flavor   race  \
# card_id
# KARA_00_07                                                NaN    NaN
# NEW1_008a                                                 NaN    NaN
# BRM_010t2                                                 NaN  BEAST
# AT_132      It's like putting racing stripes and a giant s...    NaN
# OG_141      Rejected names: Forty-Foot Faceless, Big ol' N...    NaN
#
#            how_to_earn how_to_earn_golden targeting_arrow_text faction  \
# card_id
# KARA_00_07         NaN                NaN                  NaN     NaN
# NEW1_008a          NaN                NaN                  NaN     NaN
# BRM_010t2          NaN                NaN                  NaN     NaN
# AT_132             NaN                NaN                  NaN     NaN
# OG_141             NaN                NaN                  NaN     NaN
#
#             durability
# card_id
# KARA_00_07         NaN
# NEW1_008a          NaN
# BRM_010t2          NaN
# AT_132             NaN
# OG_141             NaN

# %%
entourages_df.set_index('card_id', inplace=True)
entourages_df.head()
# Out:
#            entourage_card_id
# card_id
# KAR_A10_22        KAR_A10_09
# KAR_A10_22        KAR_A10_02
# KAR_A10_22        KAR_A10_08
# KAR_A10_22        KAR_A10_04
# KAR_A10_22        KAR_A10_05

# %%
mechanics_df.set_index('card_id', inplace=True)
mechanics_df.head()
# Out:
#                      mechanic
# card_id
# AT_132              BATTLECRY
# GVG_011a  TAG_ONE_TURN_EFFECT
# EX1_583             BATTLECRY
# LOE_007t            EVIL_GLOW
# LOE_007t   ImmuneToSpellpower

# %%
play_requirements_df.set_index('card_id', inplace=True)
play_requirements_df.head()
# Out:
#                      play_requirement  value
# card_id
# KARA_00_07       REQ_NUM_MINION_SLOTS      1
# PRO_001a         REQ_NUM_MINION_SLOTS      1
# NAX1_01          REQ_NUM_MINION_SLOTS      1
# DS1h_292_H1           REQ_STEADY_SHOT      0
# DS1h_292_H1  REQ_MINION_OR_ENEMY_HERO      0

# %% [markdown]
# ## Executing Joins
#
# Now that you have the tables loaded correctly, we're going to execute some joins. There are 4 different kinds of joins, which can best be visualized with venn diagrams:
#
# <img src='images/joins.png'>
#
# In these diagrams, each circle represents a DataFrame or SQL Table.  The left table is the table you are working with, and the right table is the table you want to join to the table you are working with.  You'll start by executing the most common type of join, an **_Inner Join_**.
#
# In the cell below, join `cards_df` with `mechanics_df` using the built-in `.join()` method on the `cards_df` object.
#
# Pass in the following parameters:
# * the table you want to join with, `mechanics_df`
# * The `how` parameter set to the type of join you want, `'inner'`

# %%
cards_with_mechanics_df = cards_df.join(mechanics_df, how)
cards_with_mechanics_df
# Out:
#                player_class         type  \
# card_id
# AT_001                 MAGE        SPELL
# AT_002                 MAGE        SPELL
# AT_003                 MAGE       MINION
# AT_004                 MAGE        SPELL
# AT_005                 MAGE        SPELL
# AT_005t             NEUTRAL       MINION
# AT_006                 MAGE       MINION
# AT_006e                MAGE  ENCHANTMENT
# AT_007                 MAGE       MINION
# AT_008                 MAGE       MINION
# AT_009                 MAGE       MINION
# AT_010               HUNTER       MINION
# AT_011               PRIEST       MINION
# AT_011e             NEUTRAL  ENCHANTMENT
# AT_012               PRIEST       MINION
# AT_013               PRIEST        SPELL
# AT_013e             NEUTRAL  ENCHANTMENT
# AT_014               PRIEST       MINION
# AT_014e              PRIEST  ENCHANTMENT
# AT_015               PRIEST        SPELL
# AT_016               PRIEST        SPELL
# AT_016e              PRIEST  ENCHANTMENT
# AT_017              NEUTRAL       MINION
# AT_017e             NEUTRAL  ENCHANTMENT
# AT_018               PRIEST       MINION
# AT_019              WARLOCK       MINION
# AT_020              WARLOCK       MINION
# AT_021              WARLOCK       MINION
# AT_021e             WARLOCK  ENCHANTMENT
# AT_022              WARLOCK        SPELL
# ...                     ...          ...
# XXX_097             NEUTRAL       MINION
# XXX_098             NEUTRAL       MINION
# XXX_099             NEUTRAL       MINION
# XXX_100             NEUTRAL       MINION
# XXX_101             NEUTRAL        SPELL
# XXX_102             NEUTRAL        SPELL
# XXX_103             NEUTRAL        SPELL
# XXX_104             NEUTRAL        SPELL
# XXX_105             NEUTRAL        SPELL
# XXX_107             NEUTRAL        SPELL
# XXX_108             NEUTRAL       MINION
# XXX_109             NEUTRAL       MINION
# XXX_110             NEUTRAL       MINION
# XXX_111             NEUTRAL        SPELL
# XXX_111e            NEUTRAL  ENCHANTMENT
# XXX_112             NEUTRAL        SPELL
# XXX_113             NEUTRAL        SPELL
# XXX_115             NEUTRAL        SPELL
# XXX_115e            NEUTRAL  ENCHANTMENT
# XXX_119             NEUTRAL        SPELL
# XXX_119e                NaN  ENCHANTMENT
# XXX_999_Crash       NEUTRAL        SPELL
# ds1_whelptoken      NEUTRAL       MINION
# hexfrog             NEUTRAL       MINION
# skele11             NEUTRAL       MINION
# skele21             NEUTRAL       MINION
# tt_004              NEUTRAL       MINION
# tt_004o             NEUTRAL  ENCHANTMENT
# tt_010                 MAGE        SPELL
# tt_010a                MAGE       MINION
#
#                                                   name      set  \
# card_id
# AT_001                                     Flame Lance      TGT
# AT_002                                          Effigy      TGT
# AT_003                                     Fallen Hero      TGT
# AT_004                                    Arcane Blast      TGT
# AT_005                                 Polymorph: Boar      TGT
# AT_005t                                           Boar      TGT
# AT_006                                Dalaran Aspirant      TGT
# AT_006e                               Power of Dalaran      TGT
# AT_007                                    Spellslinger      TGT
# AT_008                                  Coldarra Drake      TGT
# AT_009                                          Rhonin      TGT
# AT_010                                    Ram Wrangler      TGT
# AT_011                                   Holy Champion      TGT
# AT_011e                               Light's Blessing      TGT
# AT_012                                Spawn of Shadows      TGT
# AT_013                               Power Word: Glory      TGT
# AT_013e                              Power Word: Glory      TGT
# AT_014                                     Shadowfiend      TGT
# AT_014e                                  Shadowfiended      TGT
# AT_015                                         Convert      TGT
# AT_016                                         Confuse      TGT
# AT_016e                                       Confused      TGT
# AT_017                               Twilight Guardian      TGT
# AT_017e                             Twilight's Embrace      TGT
# AT_018                             Confessor Paletress      TGT
# AT_019                                      Dreadsteed      TGT
# AT_020                              Fearsome Doomguard      TGT
# AT_021                             Tiny Knight of Evil      TGT
# AT_021e                                        Felrage      TGT
# AT_022                                Fist of Jaraxxus      TGT
# ...                                                ...      ...
# XXX_097                     AI Buddy - Destroy Minions    CHEAT
# XXX_098                        AI Buddy - No Deck/Hand    CHEAT
# XXX_099                                AI Helper Buddy    CHEAT
# XXX_100                       Yogg-Saron Test (Manual)    CHEAT
# XXX_101                             Set health to full    CHEAT
# XXX_102                               Add 1 to Health.    CHEAT
# XXX_103                                Add 2 to Health    CHEAT
# XXX_104                               Add 4 to Health.    CHEAT
# XXX_105                               Add 8 to Health.    CHEAT
# XXX_107                                Set Health to 1    CHEAT
# XXX_108                    Set all minions to 1 health    CHEAT
# XXX_109                        Illidan Stormrage Cheat    CHEAT
# XXX_110                         Yogg-Saron Test (Auto)    CHEAT
# XXX_111           AI Buddy - All Charge, All Windfury!    CHEAT
# XXX_111e        All Charge, All Windfury, All The Time    CHEAT
# XXX_112                                      Fill Deck    CHEAT
# XXX_113                                          Again    CHEAT
# XXX_115                           Destroy Played Cards    CHEAT
# XXX_115e               Destroy Played Card Enchantment    CHEAT
# XXX_119                                Death No Rattle    CHEAT
# XXX_119e                               Death No Rattle    CHEAT
# XXX_999_Crash                         Crash the server    CHEAT
# ds1_whelptoken                                   Whelp  EXPERT1
# hexfrog                                           Frog     CORE
# skele11                                       Skeleton     CORE
# skele21                                  Damaged Golem  EXPERT1
# tt_004                               Flesheating Ghoul  EXPERT1
# tt_004o                                    Cannibalize  EXPERT1
# tt_010                                     Spellbender  EXPERT1
# tt_010a                                    Spellbender  EXPERT1
#
#                                                              text  cost  \
# card_id
# AT_001                                Deal $8 damage to a minion.   5.0
# AT_002          <b>Secret:</b> When a friendly minion dies, su...   3.0
# AT_003                      Your Hero Power deals 1 extra damage.   2.0
# AT_004          Deal $2 damage to a minion. This spell gets do...   1.0
# AT_005          Transform a minion into a 4/2 Boar with <b>Cha...   3.0
# AT_005t                                             <b>Charge</b>   3.0
# AT_006               <b>Inspire:</b> Gain <b>Spell Damage +1</b>.   4.0
# AT_006e                                   Increased Spell Damage.   NaN
# AT_007          <b>Battlecry:</b> Add a random spell to each p...   3.0
# AT_008           You can use your Hero Power any number of times.   6.0
# AT_009          <b>Deathrattle:</b> Add 3 copies of Arcane Mis...   8.0
# AT_010          <b>Battlecry:</b> If you have a Beast, summon ...   5.0
# AT_011            Whenever a character is healed, gain +2 Attack.   4.0
# AT_011e                                         Increased Attack.   NaN
# AT_012                <b>Inspire:</b> Deal 4 damage to each hero.   4.0
# AT_013          Choose a minion. Whenever it attacks, restore ...   1.0
# AT_013e         When this attacks, restore 4 Health to the her...   NaN
# AT_014          Whenever you draw a card, reduce its Cost by (1).   3.0
# AT_014e                                           Costs (1) less.   NaN
# AT_015              Put a copy of an enemy minion into your hand.   2.0
# AT_016                 Swap the Attack and Health of all minions.   2.0
# AT_016e                                Swapped Attack and Health.   NaN
# AT_017          <b>Battlecry:</b> If you're holding a Dragon, ...   4.0
# AT_017e                               +1 Attack and <b>Taunt</b>.   NaN
# AT_018          <b>Inspire:</b> Summon a random <b>Legendary</...   7.0
# AT_019                   <b>Deathrattle:</b> Summon a Dreadsteed.   4.0
# AT_020                                                        NaN   7.0
# AT_021                   Whenever you discard a card, gain +1/+1.   2.0
# AT_021e                                          Increased stats.   NaN
# AT_022          When you play or discard this, deal $4 damage ...   4.0
# ...                                                           ...   ...
# XXX_097                   Spawn into play to destroy all minions.   0.0
# XXX_098         Spawn into play to destroy the AI's Hand and D...   0.0
# XXX_099                             Get the AI ready for testing.   0.0
# XXX_100         <b>Battlecry:</b> Cast each spell you've cast ...   0.0
# XXX_101         Set a character's health to full, and removes ...   0.0
# XXX_102         Adds 1 health to a damaged character. Does NOT...   0.0
# XXX_103         Adds 2 health to a damaged character. Does NOT...   0.0
# XXX_104         Adds 4 health to a damaged character. Does NOT...   0.0
# XXX_105         Adds 8 health to a damaged character. Does NOT...   0.0
# XXX_107         Set a character's health to 1, and remove all ...   0.0
# XXX_108         Set every minion's health to 1, and then explo...   0.0
# XXX_109         Whenever you play a card, deal 1 damage to all...   0.0
# XXX_110         <b>Battlecry:</b> Cast 30 random spells <i>(ta...   0.0
# XXX_111         Play this card to give all minions <b>Charge</...   0.0
# XXX_111e        Your minions always have <b>Charge</b> and <b>...   NaN
# XXX_112                Fill target hero's deck with random cards.   0.0
# XXX_113                                                       NaN   0.0
# XXX_115           Whenever a player summons a minion, destroy it.   0.0
# XXX_115e          Whenever a player summons a minion, destroy it.   NaN
# XXX_119         Died without triggering <b>Deathrattle</b>, Al...   0.0
# XXX_119e        Died without triggering <b>Deathrattle</b>, Al...   NaN
# XXX_999_Crash                                    Crash the server   0.0
# ds1_whelptoken                                                NaN   1.0
# hexfrog                                              <b>Taunt</b>   0.0
# skele11                                                   <b></b>   1.0
# skele21                                                       NaN   1.0
# tt_004                    Whenever a minion dies, gain +1 Attack.   3.0
# tt_004o                                         Increased Attack.   NaN
# tt_010          <b>Secret:</b> When an enemy casts a spell on ...   3.0
# tt_010a                                                       NaN   1.0
#
#                 attack  health     rarity  collectible  \
# card_id
# AT_001             NaN     NaN     COMMON          1.0
# AT_002             NaN     NaN       RARE          1.0
# AT_003             3.0     2.0       RARE          1.0
# AT_004             NaN     NaN       EPIC          1.0
# AT_005             NaN     NaN       RARE          1.0
# AT_005t            4.0     2.0        NaN          NaN
# AT_006             3.0     5.0     COMMON          1.0
# AT_006e            NaN     NaN        NaN          NaN
# AT_007             3.0     4.0     COMMON          1.0
# AT_008             6.0     6.0       EPIC          1.0
# AT_009             7.0     7.0  LEGENDARY          1.0
# AT_010             3.0     3.0       RARE          1.0
# AT_011             3.0     5.0     COMMON          1.0
# AT_011e            NaN     NaN        NaN          NaN
# AT_012             5.0     4.0       RARE          1.0
# AT_013             NaN     NaN     COMMON          1.0
# AT_013e            NaN     NaN        NaN          NaN
# AT_014             3.0     3.0       EPIC          1.0
# AT_014e            NaN     NaN        NaN          NaN
# AT_015             NaN     NaN       RARE          1.0
# AT_016             NaN     NaN       EPIC          1.0
# AT_016e            NaN     NaN        NaN          NaN
# AT_017             2.0     6.0       EPIC          1.0
# AT_017e            NaN     NaN        NaN          NaN
# AT_018             5.0     4.0  LEGENDARY          1.0
# AT_019             1.0     1.0       EPIC          1.0
# AT_020             6.0     8.0     COMMON          1.0
# AT_021             3.0     2.0       RARE          1.0
# AT_021e            NaN     NaN        NaN          NaN
# AT_022             NaN     NaN       RARE          1.0
# ...                ...     ...        ...          ...
# XXX_097            1.0     1.0        NaN          NaN
# XXX_098            1.0     1.0        NaN          NaN
# XXX_099            1.0     1.0        NaN          NaN
# XXX_100            7.0     5.0  LEGENDARY          NaN
# XXX_101            NaN     NaN     COMMON          NaN
# XXX_102            NaN     NaN     COMMON          NaN
# XXX_103            NaN     NaN     COMMON          NaN
# XXX_104            NaN     NaN     COMMON          NaN
# XXX_105            NaN     NaN     COMMON          NaN
# XXX_107            NaN     NaN     COMMON          NaN
# XXX_108            0.0     0.0     COMMON          NaN
# XXX_109            7.0     5.0     COMMON          NaN
# XXX_110            7.0     5.0  LEGENDARY          NaN
# XXX_111            NaN     NaN     COMMON          NaN
# XXX_111e           NaN     NaN        NaN          NaN
# XXX_112            NaN     NaN     COMMON          NaN
# XXX_113            NaN     NaN     COMMON          NaN
# XXX_115            NaN     NaN     COMMON          NaN
# XXX_115e           NaN     NaN     COMMON          NaN
# XXX_119            NaN     NaN        NaN          NaN
# XXX_119e           NaN     NaN        NaN          NaN
# XXX_999_Crash      NaN     NaN     COMMON          NaN
# ds1_whelptoken     1.0     1.0        NaN          NaN
# hexfrog            0.0     1.0     COMMON          NaN
# skele11            1.0     1.0     COMMON          NaN
# skele21            2.0     1.0     COMMON          NaN
# tt_004             2.0     3.0     COMMON          1.0
# tt_004o            NaN     NaN        NaN          NaN
# tt_010             NaN     NaN       EPIC          1.0
# tt_010a            1.0     3.0       EPIC          NaN
#
#                                                            flavor        race  \
# card_id
# AT_001          It's on the rack next to ice lance, acid lance...         NaN
# AT_002                                         Burning man, brah.         NaN
# AT_003                                       And he can't get up.         NaN
# AT_004                                  Now with 100% more blast!         NaN
# AT_005                                        It's always Huffer.         NaN
# AT_005t                                                       NaN       BEAST
# AT_006           Is he aspiring or inspiring?  Make up your mind!         NaN
# AT_006e                                                       NaN         NaN
# AT_007          Does he sling spells, or do his spells linger ...         NaN
# AT_008          The Grand Tournament has a "No dragons allowed...      DRAGON
# AT_009                                     A masterless shamurai.         NaN
# AT_010             Not getting trampled is really the trick here.         NaN
# AT_011          She really likes seeing people get better.  Th...         NaN
# AT_011e                                                       NaN         NaN
# AT_012          What did you expect to happen?  He's a Spawn. ...         NaN
# AT_013          The promise of glory is a powerful tool to get...         NaN
# AT_013e                                                       NaN         NaN
# AT_014            Hopes to be promoted to "Shadowfriend" someday.         NaN
# AT_014e                                                       NaN         NaN
# AT_015               "Are you interested in... HEALTH benefits?!"         NaN
# AT_016                            This minion is really powerful!         NaN
# AT_016e                                                       NaN         NaN
# AT_017          A result of magical experiments carried out by...      DRAGON
# AT_017e                                                       NaN         NaN
# AT_018          She sees into your past and makes you face you...         NaN
# AT_019          Crescendo himself summoned this steed, riding ...       DEMON
# AT_020          They were originally called Cuddleguards, but ...       DEMON
# AT_021           "No, no, no. I asked for a tiny JESTER of evil."       DEMON
# AT_021e                                                       NaN         NaN
# AT_022                             * Not actually Jaraxxus' fist.         NaN
# ...                                                           ...         ...
# XXX_097                                                       NaN         NaN
# XXX_098                                                       NaN         NaN
# XXX_099                                                       NaN         NaN
# XXX_100                                                       NaN         NaN
# XXX_101                                                       NaN         NaN
# XXX_102                                                       NaN         NaN
# XXX_103                                                       NaN         NaN
# XXX_104                                                       NaN         NaN
# XXX_105                                                       NaN         NaN
# XXX_107                                                       NaN         NaN
# XXX_108                                                       NaN         NaN
# XXX_109                                                       NaN       DEMON
# XXX_110                                                       NaN         NaN
# XXX_111                                                       NaN         NaN
# XXX_111e                                                      NaN         NaN
# XXX_112                                                       NaN         NaN
# XXX_113                                                       NaN         NaN
# XXX_115                                                       NaN         NaN
# XXX_115e                                                      NaN         NaN
# XXX_119                                                       NaN         NaN
# XXX_119e                                                      NaN         NaN
# XXX_999_Crash                                                 NaN         NaN
# ds1_whelptoken                                                NaN      DRAGON
# hexfrog                                                       NaN       BEAST
# skele11                                                       NaN         NaN
# skele21                                                       NaN  MECHANICAL
# tt_004          'Flesheating' is an unfair name.  It's just th...         NaN
# tt_004o                                                       NaN         NaN
# tt_010          While it's fun to intercept enemy lightning bo...         NaN
# tt_010a                                                       NaN         NaN
#
#                how_to_earn how_to_earn_golden targeting_arrow_text faction  \
# card_id
# AT_001                 NaN                NaN                  NaN     NaN
# AT_002                 NaN                NaN                  NaN     NaN
# AT_003                 NaN                NaN                  NaN     NaN
# AT_004                 NaN                NaN                  NaN     NaN
# AT_005                 NaN                NaN                  NaN     NaN
# AT_005t                NaN                NaN                  NaN     NaN
# AT_006                 NaN                NaN                  NaN     NaN
# AT_006e                NaN                NaN                  NaN     NaN
# AT_007                 NaN                NaN                  NaN     NaN
# AT_008                 NaN                NaN                  NaN     NaN
# AT_009                 NaN                NaN                  NaN     NaN
# AT_010                 NaN                NaN                  NaN     NaN
# AT_011                 NaN                NaN                  NaN     NaN
# AT_011e                NaN                NaN                  NaN     NaN
# AT_012                 NaN                NaN                  NaN     NaN
# AT_013                 NaN                NaN                  NaN     NaN
# AT_013e                NaN                NaN                  NaN     NaN
# AT_014                 NaN                NaN                  NaN     NaN
# AT_014e                NaN                NaN                  NaN     NaN
# AT_015                 NaN                NaN                  NaN     NaN
# AT_016                 NaN                NaN                  NaN     NaN
# AT_016e                NaN                NaN                  NaN     NaN
# AT_017                 NaN                NaN                  NaN     NaN
# AT_017e                NaN                NaN                  NaN     NaN
# AT_018                 NaN                NaN                  NaN     NaN
# AT_019                 NaN                NaN                  NaN     NaN
# AT_020                 NaN                NaN                  NaN     NaN
# AT_021                 NaN                NaN                  NaN     NaN
# AT_021e                NaN                NaN                  NaN     NaN
# AT_022                 NaN                NaN                  NaN     NaN
# ...                    ...                ...                  ...     ...
# XXX_097                NaN                NaN                  NaN     NaN
# XXX_098                NaN                NaN                  NaN     NaN
# XXX_099                NaN                NaN                  NaN     NaN
# XXX_100                NaN                NaN                  NaN     NaN
# XXX_101                NaN                NaN                  NaN     NaN
# XXX_102                NaN                NaN                  NaN     NaN
# XXX_103                NaN                NaN                  NaN     NaN
# XXX_104                NaN                NaN                  NaN     NaN
# XXX_105                NaN                NaN                  NaN     NaN
# XXX_107                NaN                NaN                  NaN     NaN
# XXX_108                NaN                NaN                  NaN     NaN
# XXX_109                NaN                NaN                  NaN     NaN
# XXX_110                NaN                NaN                  NaN     NaN
# XXX_111                NaN                NaN                  NaN     NaN
# XXX_111e               NaN                NaN                  NaN     NaN
# XXX_112                NaN                NaN                  NaN     NaN
# XXX_113                NaN                NaN                  NaN     NaN
# XXX_115                NaN                NaN                  NaN     NaN
# XXX_115e               NaN                NaN                  NaN     NaN
# XXX_119                NaN                NaN                  NaN     NaN
# XXX_119e               NaN                NaN                  NaN     NaN
# XXX_999_Crash          NaN                NaN                  NaN     NaN
# ds1_whelptoken         NaN                NaN                  NaN     NaN
# hexfrog                NaN                NaN                  NaN     NaN
# skele11                NaN                NaN                  NaN     NaN
# skele21                NaN                NaN                  NaN     NaN
# tt_004                 NaN                NaN                  NaN     NaN
# tt_004o                NaN                NaN                  NaN     NaN
# tt_010                 NaN                NaN                  NaN     NaN
# tt_010a                NaN                NaN                  NaN     NaN
#
#                 durability              mechanic
# card_id
# AT_001                 NaN                   NaN
# AT_002                 NaN                SECRET
# AT_003                 NaN                   NaN
# AT_004                 NaN                   NaN
# AT_005                 NaN                   NaN
# AT_005t                NaN                CHARGE
# AT_006                 NaN               INSPIRE
# AT_006e                NaN                   NaN
# AT_007                 NaN             BATTLECRY
# AT_008                 NaN                   NaN
# AT_009                 NaN           DEATHRATTLE
# AT_010                 NaN             BATTLECRY
# AT_011                 NaN                   NaN
# AT_011e                NaN                  AURA
# AT_012                 NaN               INSPIRE
# AT_013                 NaN                   NaN
# AT_013e                NaN                   NaN
# AT_014                 NaN                   NaN
# AT_014e                NaN                   NaN
# AT_015                 NaN                   NaN
# AT_016                 NaN                   NaN
# AT_016e                NaN                   NaN
# AT_017                 NaN             BATTLECRY
# AT_017e                NaN                   NaN
# AT_018                 NaN               INSPIRE
# AT_019                 NaN           DEATHRATTLE
# AT_020                 NaN                   NaN
# AT_021                 NaN                   NaN
# AT_021e                NaN                   NaN
# AT_022                 NaN  InvisibleDeathrattle
# ...                    ...                   ...
# XXX_097                NaN                   NaN
# XXX_098                NaN                   NaN
# XXX_099                NaN                   NaN
# XXX_100                NaN             BATTLECRY
# XXX_101                NaN    ImmuneToSpellpower
# XXX_102                NaN    ImmuneToSpellpower
# XXX_103                NaN    ImmuneToSpellpower
# XXX_104                NaN    ImmuneToSpellpower
# XXX_105                NaN    ImmuneToSpellpower
# XXX_107                NaN    ImmuneToSpellpower
# XXX_108                NaN                   NaN
# XXX_109                NaN                   NaN
# XXX_110                NaN             BATTLECRY
# XXX_111                NaN                   NaN
# XXX_111e               NaN                   NaN
# XXX_112                NaN                   NaN
# XXX_113                NaN                   NaN
# XXX_115                NaN                   NaN
# XXX_115e               NaN                   NaN
# XXX_119                NaN                   NaN
# XXX_119e               NaN                   NaN
# XXX_999_Crash          NaN                   NaN
# ds1_whelptoken         NaN                   NaN
# hexfrog                NaN                 TAUNT
# skele11                NaN                   NaN
# skele21                NaN                   NaN
# tt_004                 NaN                   NaN
# tt_004o                NaN                   NaN
# tt_010                 NaN                SECRET
# tt_010a                NaN                   NaN
#
# [2936 rows x 18 columns]

# %% [markdown]
# Examine the output from the cell above and compare it to the original output of both the `cards_df` and `mechanics_df` DataFrame heads you displayed earlier.  Notice how it this now combines the columns from both?
#
# **_Question_**
#
# If you inspect the original `cards_df` DataFrame, you'll notice that it contains  2,819 records.  The result of our inner join, `cards_with_mechanics_df`, conntains only 1079 rows.  Why?
#
# Write your answer below this line:
# ________________________________________________________________________________
#
# First performed an inner join, which only includes records that are present in both tables.  Although there were 2819 records in the left table, there were only 1079 records that existed in both tables, which are what you see in the resulting dataframe.
#
# ## Other Types of Joins
#
# By default, the `.join()` method performs a left join if no parameter is passed in for `how=`.  In the cell below, perform a **_Left Join_** of `cards_with_mechanics_df` and `play_requirements_df`, with `cards_with_mechanics_df` as the left table.
#
# Then, display `left_join_df` to inspect our results.

# %%
left_join_df = None
left_join_df

# %% [markdown]
# Note that the results of this sort of join are dependent upon the position of each table--if you were to make `cards_with_mechanics_df` the right table and `play_requirements_df` the left table and then perform a **_Right Join_**, our results would be the same.
#
# **_Question:_**
#
# Describe what was included from each table in this join.
#
# Write your answer below this line:
# ________________________________________________________________________________
#
# Every record from `cards_with_mechanics_df`, as well as any records from `play_requirements_df` that have matching index values with a record from the left table.
#
# #### Outer Joins
#
# In the cell below, perform an outer join between `cards_df` and `dust_df`. Since these tables contain columns with the same name, we'll need to specify a suffix for at least one of them, so that the column can be renamed to avoid a naming collision.
#
# During this join, set the `rsuffix` parameter to `_dust`

# %%
outer_join_df = None
outer_join_df

# %% [markdown]
# Inspect the output above.  Note that the naming collision has been avoided by renaming the `cost` column from the right table to `cost_dust`.
#
# ## Summary
#
# In this lab, you learned how to:
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
